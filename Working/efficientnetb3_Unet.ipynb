# %% [markdown]
# <h1>Prepare Environment</h1>

# %%
from data_processing.Augmentation import *
from data_processing.helper import *

# %%
from tensorflow import keras
import tensorflow as tf
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
import time

# %% [markdown]
# <h1>Loading dataset</h1>

# %%
DATA_DIR = './CamVid/'

# %%
x_train_dir = os.path.join(DATA_DIR, 'train')
y_train_dir = os.path.join(DATA_DIR, 'trainannot')

x_valid_dir = os.path.join(DATA_DIR, 'val')
y_valid_dir = os.path.join(DATA_DIR, 'valannot')

x_test_dir = os.path.join(DATA_DIR, 'test')
y_test_dir = os.path.join(DATA_DIR, 'testannot')

# %%
# Lets look at data we have
"""
CLASSES = ['sky', 'building', 'pole', 'road', 'pavement', 
               'tree', 'signsymbol', 'fence', 'car', 
               'pedestrian', 'bicyclist', 'unlabelled']
"""
dataset = Dataset(x_train_dir, y_train_dir, 
                  classes = ['road', 'pavement', 'signsymbol','car', 
                             'pedestrian', 'bicyclist'])

image, mask = dataset[5] # get some sample

# %%
visualize(
    image=image, 
    road_mask=mask[..., 0].squeeze(),
    pavement_mask=mask[..., 1].squeeze(),
    signsymbol_mask=mask[..., 2].squeeze(),
)

# %%
visualize(
    image=image, 
    car_mask=mask[..., 3].squeeze(),
    pedestrian_mask=mask[..., 4].squeeze(),
    bicyclist_mask=mask[..., 5].squeeze(),
    background_mask=mask[..., 6].squeeze(),
)

# %% [markdown]
# <h1>Augmentation</h1>

# %%
dataset = Dataset(x_train_dir, y_train_dir, 
                  classes = ['road', 'pavement', 'signsymbol','car', 
                             'pedestrian', 'bicyclist'], 
                  augmentation=get_training_augmentation())
# Out:
# C:\Users\Admins\anaconda3\lib\site-packages\albumentations\augmentations\transforms.py:1744: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(
# C:\Users\Admins\anaconda3\lib\site-packages\albumentations\augmentations\transforms.py:1770: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(

# %%
image, mask = dataset[20] # get some sample

# %%
visualize(
    image=image, 
    road_mask=mask[..., 0].squeeze(),
    pavement_mask=mask[..., 1].squeeze(),
    signsymbol_mask=mask[..., 2].squeeze(),
)

# %%
visualize(
    image=image, 
    car_mask=mask[..., 3].squeeze(),
    pedestrian_mask=mask[..., 4].squeeze(),
    bicyclist_mask=mask[..., 5].squeeze(),
    background_mask=mask[..., 6].squeeze(),
)

# %% [markdown]
# <h1>Segmentation Model Training</h1>

# %%
import segmentation_models as sm
sm.set_framework('tf.keras')
# Out:
# Segmentation Models: using `keras` framework.

# %%
BACKBONE = 'efficientnetb3'
BATCH_SIZE = 4
CLASSES = ['road', 'pavement', 'signsymbol','car', 'pedestrian', 'bicyclist']
LR = 0.0001

# Set number of epochs
EPOCHS = 250

# Patience for the learning rate
LR_PATIENCE = 5

# Patience for early stopping
STOPPING_PATIENCE = 30

preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# define network parameters
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

#create model
model = sm.Unet(BACKBONE, classes=n_classes, activation=activation)

# %%
# define optomizer
optim = keras.optimizers.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
# set class weights for dice_loss (car: 1.; pedestrian: 2.; background: 0.5;)
dice_loss = sm.losses.DiceLoss(class_weights=np.array([1, 2, 3,4,5,6,0.5])) 
focal_loss = sm.losses.BinaryFocalLoss() if n_classes == 1 else sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 

metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, loss = total_loss, metrics = metrics)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  stem_conv (Conv2D)             (None, None, None,   1080        ['input_1[0][0]']
#                                 40)
#
#  stem_bn (BatchNormalization)   (None, None, None,   160         ['stem_conv[0][0]']
#                                 40)
#
#  stem_activation (Activation)   (None, None, None,   0           ['stem_bn[0][0]']
#                                 40)
#
#  block1a_dwconv (DepthwiseConv2  (None, None, None,   360        ['stem_activation[0][0]']
#  D)                             40)
#
#  block1a_bn (BatchNormalization  (None, None, None,   160        ['block1a_dwconv[0][0]']
#  )                              40)
#
#  block1a_activation (Activation  (None, None, None,   0          ['block1a_bn[0][0]']
#  )                              40)
#
#  block1a_se_squeeze (GlobalAver  (None, 40)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 40)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 10)     410         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 40)     440         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, None, None,   0           ['block1a_activation[0][0]',
#                                 40)                               'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, None, None,   960         ['block1a_se_excite[0][0]']
#                                 24)
#
#  block1a_project_bn (BatchNorma  (None, None, None,   96         ['block1a_project_conv[0][0]']
#  lization)                      24)
#
#  block1b_dwconv (DepthwiseConv2  (None, None, None,   216        ['block1a_project_bn[0][0]']
#  D)                             24)
#
#  block1b_bn (BatchNormalization  (None, None, None,   96         ['block1b_dwconv[0][0]']
#  )                              24)
#
#  block1b_activation (Activation  (None, None, None,   0          ['block1b_bn[0][0]']
#  )                              24)
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, None, None,   0           ['block1b_activation[0][0]',
#                                 24)                               'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, None, None,   576         ['block1b_se_excite[0][0]']
#                                 24)
#
#  block1b_project_bn (BatchNorma  (None, None, None,   96         ['block1b_project_conv[0][0]']
#  lization)                      24)
#
#  block1b_drop (FixedDropout)    (None, None, None,   0           ['block1b_project_bn[0][0]']
#                                 24)
#
#  block1b_add (Add)              (None, None, None,   0           ['block1b_drop[0][0]',
#                                 24)                               'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, None, None,   3456        ['block1b_add[0][0]']
#                                 144)
#
#  block2a_expand_bn (BatchNormal  (None, None, None,   576        ['block2a_expand_conv[0][0]']
#  ization)                       144)
#
#  block2a_expand_activation (Act  (None, None, None,   0          ['block2a_expand_bn[0][0]']
#  ivation)                       144)
#
#  block2a_dwconv (DepthwiseConv2  (None, None, None,   1296       ['block2a_expand_activation[0][0]
#  D)                             144)                             ']
#
#  block2a_bn (BatchNormalization  (None, None, None,   576        ['block2a_dwconv[0][0]']
#  )                              144)
#
#  block2a_activation (Activation  (None, None, None,   0          ['block2a_bn[0][0]']
#  )                              144)
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, None, None,   0           ['block2a_activation[0][0]',
#                                 144)                              'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, None, None,   4608        ['block2a_se_excite[0][0]']
#                                 32)
#
#  block2a_project_bn (BatchNorma  (None, None, None,   128        ['block2a_project_conv[0][0]']
#  lization)                      32)
#
#  block2b_expand_conv (Conv2D)   (None, None, None,   6144        ['block2a_project_bn[0][0]']
#                                 192)
#
#  block2b_expand_bn (BatchNormal  (None, None, None,   768        ['block2b_expand_conv[0][0]']
#  ization)                       192)
#
#  block2b_expand_activation (Act  (None, None, None,   0          ['block2b_expand_bn[0][0]']
#  ivation)                       192)
#
#  block2b_dwconv (DepthwiseConv2  (None, None, None,   1728       ['block2b_expand_activation[0][0]
#  D)                             192)                             ']
#
#  block2b_bn (BatchNormalization  (None, None, None,   768        ['block2b_dwconv[0][0]']
#  )                              192)
#
#  block2b_activation (Activation  (None, None, None,   0          ['block2b_bn[0][0]']
#  )                              192)
#
#  block2b_se_squeeze (GlobalAver  (None, 192)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, None, None,   0           ['block2b_activation[0][0]',
#                                 192)                              'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, None, None,   6144        ['block2b_se_excite[0][0]']
#                                 32)
#
#  block2b_project_bn (BatchNorma  (None, None, None,   128        ['block2b_project_conv[0][0]']
#  lization)                      32)
#
#  block2b_drop (FixedDropout)    (None, None, None,   0           ['block2b_project_bn[0][0]']
#                                 32)
#
#  block2b_add (Add)              (None, None, None,   0           ['block2b_drop[0][0]',
#                                 32)                               'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, None, None,   6144        ['block2b_add[0][0]']
#                                 192)
#
#  block2c_expand_bn (BatchNormal  (None, None, None,   768        ['block2c_expand_conv[0][0]']
#  ization)                       192)
#
#  block2c_expand_activation (Act  (None, None, None,   0          ['block2c_expand_bn[0][0]']
#  ivation)                       192)
#
#  block2c_dwconv (DepthwiseConv2  (None, None, None,   1728       ['block2c_expand_activation[0][0]
#  D)                             192)                             ']
#
#  block2c_bn (BatchNormalization  (None, None, None,   768        ['block2c_dwconv[0][0]']
#  )                              192)
#
#  block2c_activation (Activation  (None, None, None,   0          ['block2c_bn[0][0]']
#  )                              192)
#
#  block2c_se_squeeze (GlobalAver  (None, 192)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, None, None,   0           ['block2c_activation[0][0]',
#                                 192)                              'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, None, None,   6144        ['block2c_se_excite[0][0]']
#                                 32)
#
#  block2c_project_bn (BatchNorma  (None, None, None,   128        ['block2c_project_conv[0][0]']
#  lization)                      32)
#
#  block2c_drop (FixedDropout)    (None, None, None,   0           ['block2c_project_bn[0][0]']
#                                 32)
#
#  block2c_add (Add)              (None, None, None,   0           ['block2c_drop[0][0]',
#                                 32)                               'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, None, None,   6144        ['block2c_add[0][0]']
#                                 192)
#
#  block3a_expand_bn (BatchNormal  (None, None, None,   768        ['block3a_expand_conv[0][0]']
#  ization)                       192)
#
#  block3a_expand_activation (Act  (None, None, None,   0          ['block3a_expand_bn[0][0]']
#  ivation)                       192)
#
#  block3a_dwconv (DepthwiseConv2  (None, None, None,   4800       ['block3a_expand_activation[0][0]
#  D)                             192)                             ']
#
#  block3a_bn (BatchNormalization  (None, None, None,   768        ['block3a_dwconv[0][0]']
#  )                              192)
#
#  block3a_activation (Activation  (None, None, None,   0          ['block3a_bn[0][0]']
#  )                              192)
#
#  block3a_se_squeeze (GlobalAver  (None, 192)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, None, None,   0           ['block3a_activation[0][0]',
#                                 192)                              'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, None, None,   9216        ['block3a_se_excite[0][0]']
#                                 48)
#
#  block3a_project_bn (BatchNorma  (None, None, None,   192        ['block3a_project_conv[0][0]']
#  lization)                      48)
#
#  block3b_expand_conv (Conv2D)   (None, None, None,   13824       ['block3a_project_bn[0][0]']
#                                 288)
#
#  block3b_expand_bn (BatchNormal  (None, None, None,   1152       ['block3b_expand_conv[0][0]']
#  ization)                       288)
#
#  block3b_expand_activation (Act  (None, None, None,   0          ['block3b_expand_bn[0][0]']
#  ivation)                       288)
#
#  block3b_dwconv (DepthwiseConv2  (None, None, None,   7200       ['block3b_expand_activation[0][0]
#  D)                             288)                             ']
#
#  block3b_bn (BatchNormalization  (None, None, None,   1152       ['block3b_dwconv[0][0]']
#  )                              288)
#
#  block3b_activation (Activation  (None, None, None,   0          ['block3b_bn[0][0]']
#  )                              288)
#
#  block3b_se_squeeze (GlobalAver  (None, 288)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, None, None,   0           ['block3b_activation[0][0]',
#                                 288)                              'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, None, None,   13824       ['block3b_se_excite[0][0]']
#                                 48)
#
#  block3b_project_bn (BatchNorma  (None, None, None,   192        ['block3b_project_conv[0][0]']
#  lization)                      48)
#
#  block3b_drop (FixedDropout)    (None, None, None,   0           ['block3b_project_bn[0][0]']
#                                 48)
#
#  block3b_add (Add)              (None, None, None,   0           ['block3b_drop[0][0]',
#                                 48)                               'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, None, None,   13824       ['block3b_add[0][0]']
#                                 288)
#
#  block3c_expand_bn (BatchNormal  (None, None, None,   1152       ['block3c_expand_conv[0][0]']
#  ization)                       288)
#
#  block3c_expand_activation (Act  (None, None, None,   0          ['block3c_expand_bn[0][0]']
#  ivation)                       288)
#
#  block3c_dwconv (DepthwiseConv2  (None, None, None,   7200       ['block3c_expand_activation[0][0]
#  D)                             288)                             ']
#
#  block3c_bn (BatchNormalization  (None, None, None,   1152       ['block3c_dwconv[0][0]']
#  )                              288)
#
#  block3c_activation (Activation  (None, None, None,   0          ['block3c_bn[0][0]']
#  )                              288)
#
#  block3c_se_squeeze (GlobalAver  (None, 288)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, None, None,   0           ['block3c_activation[0][0]',
#                                 288)                              'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, None, None,   13824       ['block3c_se_excite[0][0]']
#                                 48)
#
#  block3c_project_bn (BatchNorma  (None, None, None,   192        ['block3c_project_conv[0][0]']
#  lization)                      48)
#
#  block3c_drop (FixedDropout)    (None, None, None,   0           ['block3c_project_bn[0][0]']
#                                 48)
#
#  block3c_add (Add)              (None, None, None,   0           ['block3c_drop[0][0]',
#                                 48)                               'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, None, None,   13824       ['block3c_add[0][0]']
#                                 288)
#
#  block4a_expand_bn (BatchNormal  (None, None, None,   1152       ['block4a_expand_conv[0][0]']
#  ization)                       288)
#
#  block4a_expand_activation (Act  (None, None, None,   0          ['block4a_expand_bn[0][0]']
#  ivation)                       288)
#
#  block4a_dwconv (DepthwiseConv2  (None, None, None,   2592       ['block4a_expand_activation[0][0]
#  D)                             288)                             ']
#
#  block4a_bn (BatchNormalization  (None, None, None,   1152       ['block4a_dwconv[0][0]']
#  )                              288)
#
#  block4a_activation (Activation  (None, None, None,   0          ['block4a_bn[0][0]']
#  )                              288)
#
#  block4a_se_squeeze (GlobalAver  (None, 288)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, None, None,   0           ['block4a_activation[0][0]',
#                                 288)                              'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, None, None,   27648       ['block4a_se_excite[0][0]']
#                                 96)
#
#  block4a_project_bn (BatchNorma  (None, None, None,   384        ['block4a_project_conv[0][0]']
#  lization)                      96)
#
#  block4b_expand_conv (Conv2D)   (None, None, None,   55296       ['block4a_project_bn[0][0]']
#                                 576)
#
#  block4b_expand_bn (BatchNormal  (None, None, None,   2304       ['block4b_expand_conv[0][0]']
#  ization)                       576)
#
#  block4b_expand_activation (Act  (None, None, None,   0          ['block4b_expand_bn[0][0]']
#  ivation)                       576)
#
#  block4b_dwconv (DepthwiseConv2  (None, None, None,   5184       ['block4b_expand_activation[0][0]
#  D)                             576)                             ']
#
#  block4b_bn (BatchNormalization  (None, None, None,   2304       ['block4b_dwconv[0][0]']
#  )                              576)
#
#  block4b_activation (Activation  (None, None, None,   0          ['block4b_bn[0][0]']
#  )                              576)
#
#  block4b_se_squeeze (GlobalAver  (None, 576)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, None, None,   0           ['block4b_activation[0][0]',
#                                 576)                              'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, None, None,   55296       ['block4b_se_excite[0][0]']
#                                 96)
#
#  block4b_project_bn (BatchNorma  (None, None, None,   384        ['block4b_project_conv[0][0]']
#  lization)                      96)
#
#  block4b_drop (FixedDropout)    (None, None, None,   0           ['block4b_project_bn[0][0]']
#                                 96)
#
#  block4b_add (Add)              (None, None, None,   0           ['block4b_drop[0][0]',
#                                 96)                               'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, None, None,   55296       ['block4b_add[0][0]']
#                                 576)
#
#  block4c_expand_bn (BatchNormal  (None, None, None,   2304       ['block4c_expand_conv[0][0]']
#  ization)                       576)
#
#  block4c_expand_activation (Act  (None, None, None,   0          ['block4c_expand_bn[0][0]']
#  ivation)                       576)
#
#  block4c_dwconv (DepthwiseConv2  (None, None, None,   5184       ['block4c_expand_activation[0][0]
#  D)                             576)                             ']
#
#  block4c_bn (BatchNormalization  (None, None, None,   2304       ['block4c_dwconv[0][0]']
#  )                              576)
#
#  block4c_activation (Activation  (None, None, None,   0          ['block4c_bn[0][0]']
#  )                              576)
#
#  block4c_se_squeeze (GlobalAver  (None, 576)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, None, None,   0           ['block4c_activation[0][0]',
#                                 576)                              'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, None, None,   55296       ['block4c_se_excite[0][0]']
#                                 96)
#
#  block4c_project_bn (BatchNorma  (None, None, None,   384        ['block4c_project_conv[0][0]']
#  lization)                      96)
#
#  block4c_drop (FixedDropout)    (None, None, None,   0           ['block4c_project_bn[0][0]']
#                                 96)
#
#  block4c_add (Add)              (None, None, None,   0           ['block4c_drop[0][0]',
#                                 96)                               'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, None, None,   55296       ['block4c_add[0][0]']
#                                 576)
#
#  block4d_expand_bn (BatchNormal  (None, None, None,   2304       ['block4d_expand_conv[0][0]']
#  ization)                       576)
#
#  block4d_expand_activation (Act  (None, None, None,   0          ['block4d_expand_bn[0][0]']
#  ivation)                       576)
#
#  block4d_dwconv (DepthwiseConv2  (None, None, None,   5184       ['block4d_expand_activation[0][0]
#  D)                             576)                             ']
#
#  block4d_bn (BatchNormalization  (None, None, None,   2304       ['block4d_dwconv[0][0]']
#  )                              576)
#
#  block4d_activation (Activation  (None, None, None,   0          ['block4d_bn[0][0]']
#  )                              576)
#
#  block4d_se_squeeze (GlobalAver  (None, 576)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, None, None,   0           ['block4d_activation[0][0]',
#                                 576)                              'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, None, None,   55296       ['block4d_se_excite[0][0]']
#                                 96)
#
#  block4d_project_bn (BatchNorma  (None, None, None,   384        ['block4d_project_conv[0][0]']
#  lization)                      96)
#
#  block4d_drop (FixedDropout)    (None, None, None,   0           ['block4d_project_bn[0][0]']
#                                 96)
#
#  block4d_add (Add)              (None, None, None,   0           ['block4d_drop[0][0]',
#                                 96)                               'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, None, None,   55296       ['block4d_add[0][0]']
#                                 576)
#
#  block4e_expand_bn (BatchNormal  (None, None, None,   2304       ['block4e_expand_conv[0][0]']
#  ization)                       576)
#
#  block4e_expand_activation (Act  (None, None, None,   0          ['block4e_expand_bn[0][0]']
# ...
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 2304)   223488      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, None, None,   0           ['block7b_activation[0][0]',
#                                 2304)                             'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, None, None,   884736      ['block7b_se_excite[0][0]']
#                                 384)
#
#  block7b_project_bn (BatchNorma  (None, None, None,   1536       ['block7b_project_conv[0][0]']
#  lization)                      384)
#
#  block7b_drop (FixedDropout)    (None, None, None,   0           ['block7b_project_bn[0][0]']
#                                 384)
#
#  block7b_add (Add)              (None, None, None,   0           ['block7b_drop[0][0]',
#                                 384)                              'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)              (None, None, None,   589824      ['block7b_add[0][0]']
#                                 1536)
#
#  top_bn (BatchNormalization)    (None, None, None,   6144        ['top_conv[0][0]']
#                                 1536)
#
#  top_activation (Activation)    (None, None, None,   0           ['top_bn[0][0]']
#                                 1536)
#
#  decoder_stage0_upsampling (UpS  (None, None, None,   0          ['top_activation[0][0]']
#  ampling2D)                     1536)
#
#  decoder_stage0_concat (Concate  (None, None, None,   0          ['decoder_stage0_upsampling[0][0]
#  nate)                          2352)                            ',
#                                                                   'block6a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage0a_conv (Conv2D)  (None, None, None,   5419008     ['decoder_stage0_concat[0][0]']
#                                 256)
#
#  decoder_stage0a_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0a_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0a_relu (Activati  (None, None, None,   0          ['decoder_stage0a_bn[0][0]']
#  on)                            256)
#
#  decoder_stage0b_conv (Conv2D)  (None, None, None,   589824      ['decoder_stage0a_relu[0][0]']
#                                 256)
#
#  decoder_stage0b_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0b_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0b_relu (Activati  (None, None, None,   0          ['decoder_stage0b_bn[0][0]']
#  on)                            256)
#
#  decoder_stage1_upsampling (UpS  (None, None, None,   0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)                     256)
#
#  decoder_stage1_concat (Concate  (None, None, None,   0          ['decoder_stage1_upsampling[0][0]
#  nate)                          544)                             ',
#                                                                   'block4a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage1a_conv (Conv2D)  (None, None, None,   626688      ['decoder_stage1_concat[0][0]']
#                                 128)
#
#  decoder_stage1a_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1a_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1a_relu (Activati  (None, None, None,   0          ['decoder_stage1a_bn[0][0]']
#  on)                            128)
#
#  decoder_stage1b_conv (Conv2D)  (None, None, None,   147456      ['decoder_stage1a_relu[0][0]']
#                                 128)
#
#  decoder_stage1b_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1b_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1b_relu (Activati  (None, None, None,   0          ['decoder_stage1b_bn[0][0]']
#  on)                            128)
#
#  decoder_stage2_upsampling (UpS  (None, None, None,   0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)                     128)
#
#  decoder_stage2_concat (Concate  (None, None, None,   0          ['decoder_stage2_upsampling[0][0]
#  nate)                          320)                             ',
#                                                                   'block3a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage2a_conv (Conv2D)  (None, None, None,   184320      ['decoder_stage2_concat[0][0]']
#                                 64)
#
#  decoder_stage2a_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2a_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2a_relu (Activati  (None, None, None,   0          ['decoder_stage2a_bn[0][0]']
#  on)                            64)
#
#  decoder_stage2b_conv (Conv2D)  (None, None, None,   36864       ['decoder_stage2a_relu[0][0]']
#                                 64)
#
#  decoder_stage2b_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2b_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2b_relu (Activati  (None, None, None,   0          ['decoder_stage2b_bn[0][0]']
#  on)                            64)
#
#  decoder_stage3_upsampling (UpS  (None, None, None,   0          ['decoder_stage2b_relu[0][0]']
#  ampling2D)                     64)
#
#  decoder_stage3_concat (Concate  (None, None, None,   0          ['decoder_stage3_upsampling[0][0]
#  nate)                          208)                             ',
#                                                                   'block2a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage3a_conv (Conv2D)  (None, None, None,   59904       ['decoder_stage3_concat[0][0]']
#                                 32)
#
#  decoder_stage3a_bn (BatchNorma  (None, None, None,   128        ['decoder_stage3a_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3a_relu (Activati  (None, None, None,   0          ['decoder_stage3a_bn[0][0]']
#  on)                            32)
#
#  decoder_stage3b_conv (Conv2D)  (None, None, None,   9216        ['decoder_stage3a_relu[0][0]']
#                                 32)
#
#  decoder_stage3b_bn (BatchNorma  (None, None, None,   128        ['decoder_stage3b_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3b_relu (Activati  (None, None, None,   0          ['decoder_stage3b_bn[0][0]']
#  on)                            32)
#
#  decoder_stage4_upsampling (UpS  (None, None, None,   0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     32)
#
#  decoder_stage4a_conv (Conv2D)  (None, None, None,   4608        ['decoder_stage4_upsampling[0][0]
#                                 16)                              ']
#
#  decoder_stage4a_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4a_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4a_relu (Activati  (None, None, None,   0          ['decoder_stage4a_bn[0][0]']
#  on)                            16)
#
#  decoder_stage4b_conv (Conv2D)  (None, None, None,   2304        ['decoder_stage4a_relu[0][0]']
#                                 16)
#
#  decoder_stage4b_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4b_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4b_relu (Activati  (None, None, None,   0          ['decoder_stage4b_bn[0][0]']
#  on)                            16)
#
#  final_conv (Conv2D)            (None, None, None,   1015        ['decoder_stage4b_relu[0][0]']
#                                 7)
#
#  softmax (Activation)           (None, None, None,   0           ['final_conv[0][0]']
#                                 7)
#
# ==================================================================================================
# Total params: 17,868,703
# Trainable params: 17,779,423
# Non-trainable params: 89,280
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
assert train_dataloader[0][0].shape == (BATCH_SIZE, 320, 320, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 320, 320, n_classes)

# %%
from tensorflow.keras.callbacks import EarlyStopping
# define callbacks for learning rate scheduling and best checkpoints saving
checkpoint = tf.keras.callbacks.ModelCheckpoint('./checkpoint/efficientnetb3_Unet.h5', monitor='val_loss',save_weights_only=True, save_best_only=True, mode='min')
learning_rate = tf.keras.callbacks.ReduceLROnPlateau(patience=LR_PATIENCE, verbose=1, factor=0.5, min_delta=0.00001)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=STOPPING_PATIENCE, verbose=1, restore_best_weights=True)

# %%
# train model
pre_train = time.time()
history = model.fit_generator(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=EPOCHS, 
    callbacks=[learning_rate,early_stopping,checkpoint], 
    validation_data=valid_dataloader, 
    validation_steps=len(valid_dataloader),
)
time_training = time.time() - pre_train
# Out:
# /home/waflol/anaconda3/lib/python3.8/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/250
# 91/91 [==============================] - 52s 415ms/step - loss: 0.8448 - iou_score: 0.1385 - f1-score: 0.1928 - val_loss: 0.7786 - val_iou_score: 0.2429 - val_f1-score: 0.2857
# Epoch 2/250
# 91/91 [==============================] - 37s 403ms/step - loss: 0.7274 - iou_score: 0.3033 - f1-score: 0.3598 - val_loss: 0.7067 - val_iou_score: 0.3179 - val_f1-score: 0.3756
# Epoch 3/250
# 91/91 [==============================] - 36s 391ms/step - loss: 0.6657 - iou_score: 0.3666 - f1-score: 0.4276 - val_loss: 0.6532 - val_iou_score: 0.3631 - val_f1-score: 0.4190
# Epoch 4/250
# 91/91 [==============================] - 36s 393ms/step - loss: 0.6317 - iou_score: 0.3859 - f1-score: 0.4434 - val_loss: 0.6238 - val_iou_score: 0.3797 - val_f1-score: 0.4336
# Epoch 5/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.6138 - iou_score: 0.3939 - f1-score: 0.4504 - val_loss: 0.5644 - val_iou_score: 0.4127 - val_f1-score: 0.4587
# Epoch 6/250
# 91/91 [==============================] - 36s 394ms/step - loss: 0.5922 - iou_score: 0.4078 - f1-score: 0.4615 - val_loss: 0.5586 - val_iou_score: 0.4074 - val_f1-score: 0.4572
# Epoch 7/250
# 91/91 [==============================] - 36s 395ms/step - loss: 0.5790 - iou_score: 0.4138 - f1-score: 0.4720 - val_loss: 0.5298 - val_iou_score: 0.4141 - val_f1-score: 0.4624
# Epoch 8/250
# 91/91 [==============================] - 37s 403ms/step - loss: 0.5632 - iou_score: 0.4299 - f1-score: 0.4913 - val_loss: 0.5134 - val_iou_score: 0.4323 - val_f1-score: 0.4851
# Epoch 9/250
# 91/91 [==============================] - 36s 394ms/step - loss: 0.5619 - iou_score: 0.4379 - f1-score: 0.5020 - val_loss: 0.4953 - val_iou_score: 0.4608 - val_f1-score: 0.5353
# Epoch 10/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.5488 - iou_score: 0.4499 - f1-score: 0.5168 - val_loss: 0.4900 - val_iou_score: 0.4695 - val_f1-score: 0.5473
# Epoch 11/250
# 91/91 [==============================] - 36s 400ms/step - loss: 0.5421 - iou_score: 0.4677 - f1-score: 0.5430 - val_loss: 0.4746 - val_iou_score: 0.5179 - val_f1-score: 0.6159
# Epoch 12/250
# 91/91 [==============================] - 36s 395ms/step - loss: 0.5283 - iou_score: 0.4806 - f1-score: 0.5605 - val_loss: 0.4912 - val_iou_score: 0.4798 - val_f1-score: 0.5694
# Epoch 13/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.5246 - iou_score: 0.4785 - f1-score: 0.5578 - val_loss: 0.4391 - val_iou_score: 0.5602 - val_f1-score: 0.6614
# Epoch 14/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.5122 - iou_score: 0.4877 - f1-score: 0.5667 - val_loss: 0.4494 - val_iou_score: 0.5372 - val_f1-score: 0.6379
# Epoch 15/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.5006 - iou_score: 0.4951 - f1-score: 0.5763 - val_loss: 0.4104 - val_iou_score: 0.5765 - val_f1-score: 0.6802
# Epoch 16/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.4926 - iou_score: 0.4991 - f1-score: 0.5796 - val_loss: 0.3975 - val_iou_score: 0.5976 - val_f1-score: 0.6995
# Epoch 17/250
# 91/91 [==============================] - 36s 397ms/step - loss: 0.4927 - iou_score: 0.4986 - f1-score: 0.5796 - val_loss: 0.4163 - val_iou_score: 0.5799 - val_f1-score: 0.6833
# Epoch 18/250
# 91/91 [==============================] - 36s 399ms/step - loss: 0.4830 - iou_score: 0.5097 - f1-score: 0.5904 - val_loss: 0.4054 - val_iou_score: 0.5813 - val_f1-score: 0.6858
# Epoch 19/250
# 91/91 [==============================] - 37s 404ms/step - loss: 0.4733 - iou_score: 0.5160 - f1-score: 0.5968 - val_loss: 0.3865 - val_iou_score: 0.5961 - val_f1-score: 0.7045
# Epoch 20/250
# 91/91 [==============================] - 38s 411ms/step - loss: 0.4752 - iou_score: 0.5142 - f1-score: 0.5973 - val_loss: 0.4102 - val_iou_score: 0.5674 - val_f1-score: 0.6707
# Epoch 21/250
# 91/91 [==============================] - 38s 413ms/step - loss: 0.4749 - iou_score: 0.5141 - f1-score: 0.5975 - val_loss: 0.4162 - val_iou_score: 0.5727 - val_f1-score: 0.6815
# Epoch 22/250
# 91/91 [==============================] - 37s 410ms/step - loss: 0.4598 - iou_score: 0.5166 - f1-score: 0.5999 - val_loss: 0.3902 - val_iou_score: 0.5964 - val_f1-score: 0.7005
# Epoch 23/250
# 91/91 [==============================] - 37s 411ms/step - loss: 0.4487 - iou_score: 0.5234 - f1-score: 0.6066 - val_loss: 0.4199 - val_iou_score: 0.5500 - val_f1-score: 0.6507
# Epoch 24/250
# 91/91 [==============================] - 36s 398ms/step - loss: 0.4473 - iou_score: 0.5224 - f1-score: 0.6061 - val_loss: 0.3839 - val_iou_score: 0.5907 - val_f1-score: 0.6982
# Epoch 25/250
# 91/91 [==============================] - 36s 399ms/step - loss: 0.4459 - iou_score: 0.5260 - f1-score: 0.6101 - val_loss: 0.3861 - val_iou_score: 0.5898 - val_f1-score: 0.6956
# Epoch 26/250
# 91/91 [==============================] - 36s 398ms/step - loss: 0.4391 - iou_score: 0.5284 - f1-score: 0.6126 - val_loss: 0.3784 - val_iou_score: 0.5987 - val_f1-score: 0.7016
# Epoch 27/250
# 91/91 [==============================] - 36s 399ms/step - loss: 0.4368 - iou_score: 0.5304 - f1-score: 0.6152 - val_loss: 0.3778 - val_iou_score: 0.6010 - val_f1-score: 0.7064
# Epoch 28/250
# 91/91 [==============================] - 36s 398ms/step - loss: 0.4317 - iou_score: 0.5355 - f1-score: 0.6205 - val_loss: 0.3709 - val_iou_score: 0.6036 - val_f1-score: 0.7075
# Epoch 29/250
# 91/91 [==============================] - 36s 397ms/step - loss: 0.4360 - iou_score: 0.5304 - f1-score: 0.6144 - val_loss: 0.3865 - val_iou_score: 0.5841 - val_f1-score: 0.6911
# Epoch 30/250
# 91/91 [==============================] - 36s 399ms/step - loss: 0.4283 - iou_score: 0.5369 - f1-score: 0.6211 - val_loss: 0.3534 - val_iou_score: 0.6181 - val_f1-score: 0.7239
# Epoch 31/250
# 91/91 [==============================] - 37s 404ms/step - loss: 0.4231 - iou_score: 0.5426 - f1-score: 0.6272 - val_loss: 0.3706 - val_iou_score: 0.6029 - val_f1-score: 0.7111
# Epoch 32/250
# 91/91 [==============================] - 36s 398ms/step - loss: 0.4232 - iou_score: 0.5414 - f1-score: 0.6262 - val_loss: 0.3709 - val_iou_score: 0.6009 - val_f1-score: 0.7070
# Epoch 33/250
# 91/91 [==============================] - 36s 398ms/step - loss: 0.4188 - iou_score: 0.5460 - f1-score: 0.6302 - val_loss: 0.4138 - val_iou_score: 0.5554 - val_f1-score: 0.6593
# Epoch 34/250
# 91/91 [==============================] - 36s 398ms/step - loss: 0.4196 - iou_score: 0.5465 - f1-score: 0.6295 - val_loss: 0.3538 - val_iou_score: 0.6172 - val_f1-score: 0.7223
# Epoch 35/250
# 91/91 [==============================] - 36s 397ms/step - loss: 0.4161 - iou_score: 0.5465 - f1-score: 0.6307 - val_loss: 0.3642 - val_iou_score: 0.6163 - val_f1-score: 0.7217
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 36/250
# 91/91 [==============================] - 36s 397ms/step - loss: 0.4103 - iou_score: 0.5529 - f1-score: 0.6369 - val_loss: 0.3476 - val_iou_score: 0.6226 - val_f1-score: 0.7282
# Epoch 37/250
# 91/91 [==============================] - 36s 399ms/step - loss: 0.4091 - iou_score: 0.5537 - f1-score: 0.6375 - val_loss: 0.3420 - val_iou_score: 0.6249 - val_f1-score: 0.7305
# Epoch 38/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.4093 - iou_score: 0.5555 - f1-score: 0.6415 - val_loss: 0.3447 - val_iou_score: 0.6229 - val_f1-score: 0.7284
# Epoch 39/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.4086 - iou_score: 0.5545 - f1-score: 0.6379 - val_loss: 0.3566 - val_iou_score: 0.6175 - val_f1-score: 0.7245
# Epoch 40/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.4043 - iou_score: 0.5601 - f1-score: 0.6434 - val_loss: 0.3504 - val_iou_score: 0.6149 - val_f1-score: 0.7196
# Epoch 41/250
# 91/91 [==============================] - 36s 395ms/step - loss: 0.4080 - iou_score: 0.5562 - f1-score: 0.6400 - val_loss: 0.3448 - val_iou_score: 0.6261 - val_f1-score: 0.7304
# Epoch 42/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.4054 - iou_score: 0.5595 - f1-score: 0.6426 - val_loss: 0.3440 - val_iou_score: 0.6248 - val_f1-score: 0.7310
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 43/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.4056 - iou_score: 0.5576 - f1-score: 0.6421 - val_loss: 0.3340 - val_iou_score: 0.6328 - val_f1-score: 0.7365
# Epoch 44/250
# 91/91 [==============================] - 36s 397ms/step - loss: 0.4045 - iou_score: 0.5588 - f1-score: 0.6420 - val_loss: 0.3315 - val_iou_score: 0.6365 - val_f1-score: 0.7418
# Epoch 45/250
# 91/91 [==============================] - 36s 395ms/step - loss: 0.4040 - iou_score: 0.5606 - f1-score: 0.6447 - val_loss: 0.3414 - val_iou_score: 0.6300 - val_f1-score: 0.7328
# Epoch 46/250
# 91/91 [==============================] - 36s 395ms/step - loss: 0.4040 - iou_score: 0.5592 - f1-score: 0.6424 - val_loss: 0.3470 - val_iou_score: 0.6249 - val_f1-score: 0.7290
# Epoch 47/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.3984 - iou_score: 0.5632 - f1-score: 0.6470 - val_loss: 0.3480 - val_iou_score: 0.6238 - val_f1-score: 0.7277
# Epoch 48/250
# 91/91 [==============================] - 36s 398ms/step - loss: 0.3992 - iou_score: 0.5633 - f1-score: 0.6460 - val_loss: 0.3507 - val_iou_score: 0.6208 - val_f1-score: 0.7255
# Epoch 49/250
# 91/91 [==============================] - 36s 395ms/step - loss: 0.3972 - iou_score: 0.5636 - f1-score: 0.6478 - val_loss: 0.3450 - val_iou_score: 0.6240 - val_f1-score: 0.7308
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 50/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.3965 - iou_score: 0.5657 - f1-score: 0.6502 - val_loss: 0.3444 - val_iou_score: 0.6241 - val_f1-score: 0.7291
# Epoch 51/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.4028 - iou_score: 0.5608 - f1-score: 0.6453 - val_loss: 0.3464 - val_iou_score: 0.6232 - val_f1-score: 0.7270
# Epoch 52/250
# 91/91 [==============================] - 36s 394ms/step - loss: 0.3972 - iou_score: 0.5648 - f1-score: 0.6486 - val_loss: 0.3442 - val_iou_score: 0.6246 - val_f1-score: 0.7290
# Epoch 53/250
# 91/91 [==============================] - 36s 395ms/step - loss: 0.3969 - iou_score: 0.5637 - f1-score: 0.6472 - val_loss: 0.3460 - val_iou_score: 0.6224 - val_f1-score: 0.7274
# Epoch 54/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.3985 - iou_score: 0.5630 - f1-score: 0.6468 - val_loss: 0.3404 - val_iou_score: 0.6279 - val_f1-score: 0.7332
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 55/250
# 91/91 [==============================] - 36s 395ms/step - loss: 0.4010 - iou_score: 0.5630 - f1-score: 0.6466 - val_loss: 0.3418 - val_iou_score: 0.6267 - val_f1-score: 0.7304
# Epoch 56/250
# 91/91 [==============================] - 37s 400ms/step - loss: 0.4015 - iou_score: 0.5630 - f1-score: 0.6481 - val_loss: 0.3411 - val_iou_score: 0.6273 - val_f1-score: 0.7317
# Epoch 57/250
# 91/91 [==============================] - 36s 397ms/step - loss: 0.3971 - iou_score: 0.5654 - f1-score: 0.6500 - val_loss: 0.3403 - val_iou_score: 0.6275 - val_f1-score: 0.7316
# Epoch 58/250
# 91/91 [==============================] - 36s 397ms/step - loss: 0.3962 - iou_score: 0.5664 - f1-score: 0.6498 - val_loss: 0.3394 - val_iou_score: 0.6284 - val_f1-score: 0.7320
# Epoch 59/250
# 91/91 [==============================] - 36s 397ms/step - loss: 0.3970 - iou_score: 0.5654 - f1-score: 0.6478 - val_loss: 0.3383 - val_iou_score: 0.6299 - val_f1-score: 0.7341
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 60/250
# 91/91 [==============================] - 36s 398ms/step - loss: 0.3931 - iou_score: 0.5670 - f1-score: 0.6506 - val_loss: 0.3367 - val_iou_score: 0.6310 - val_f1-score: 0.7348
# Epoch 61/250
# 91/91 [==============================] - 36s 397ms/step - loss: 0.4020 - iou_score: 0.5638 - f1-score: 0.6470 - val_loss: 0.3372 - val_iou_score: 0.6301 - val_f1-score: 0.7338
# Epoch 62/250
# 91/91 [==============================] - 36s 397ms/step - loss: 0.3965 - iou_score: 0.5678 - f1-score: 0.6511 - val_loss: 0.3361 - val_iou_score: 0.6305 - val_f1-score: 0.7341
# Epoch 63/250
# 91/91 [==============================] - 36s 397ms/step - loss: 0.3963 - iou_score: 0.5667 - f1-score: 0.6502 - val_loss: 0.3367 - val_iou_score: 0.6299 - val_f1-score: 0.7335
# Epoch 64/250
# 91/91 [==============================] - 36s 397ms/step - loss: 0.3902 - iou_score: 0.5720 - f1-score: 0.6552 - val_loss: 0.3360 - val_iou_score: 0.6306 - val_f1-score: 0.7343
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 65/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.3931 - iou_score: 0.5692 - f1-score: 0.6530 - val_loss: 0.3361 - val_iou_score: 0.6304 - val_f1-score: 0.7341
# Epoch 66/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.3926 - iou_score: 0.5716 - f1-score: 0.6554 - val_loss: 0.3363 - val_iou_score: 0.6303 - val_f1-score: 0.7342
# Epoch 67/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.3964 - iou_score: 0.5664 - f1-score: 0.6506 - val_loss: 0.3376 - val_iou_score: 0.6296 - val_f1-score: 0.7333
# Epoch 68/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.3940 - iou_score: 0.5686 - f1-score: 0.6522 - val_loss: 0.3373 - val_iou_score: 0.6300 - val_f1-score: 0.7336
# Epoch 69/250
# 91/91 [==============================] - 36s 400ms/step - loss: 0.3939 - iou_score: 0.5680 - f1-score: 0.6519 - val_loss: 0.3386 - val_iou_score: 0.6286 - val_f1-score: 0.7322
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 70/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.3899 - iou_score: 0.5718 - f1-score: 0.6550 - val_loss: 0.3393 - val_iou_score: 0.6284 - val_f1-score: 0.7321
# Epoch 71/250
# 91/91 [==============================] - 36s 397ms/step - loss: 0.3973 - iou_score: 0.5635 - f1-score: 0.6481 - val_loss: 0.3382 - val_iou_score: 0.6291 - val_f1-score: 0.7330
# Epoch 72/250
# 91/91 [==============================] - 36s 397ms/step - loss: 0.3958 - iou_score: 0.5664 - f1-score: 0.6508 - val_loss: 0.3377 - val_iou_score: 0.6298 - val_f1-score: 0.7332
# Epoch 73/250
# 91/91 [==============================] - 36s 397ms/step - loss: 0.3926 - iou_score: 0.5692 - f1-score: 0.6529 - val_loss: 0.3388 - val_iou_score: 0.6288 - val_f1-score: 0.7323
# Epoch 74/250
# 91/91 [==============================] - 36s 396ms/step - loss: 0.3941 - iou_score: 0.5683 - f1-score: 0.6514 - val_loss: 0.3376 - val_iou_score: 0.6299 - val_f1-score: 0.7335
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Restoring model weights from the end of the best epoch.
# Epoch 00074: early stopping

# %% [markdown]
# <h1>Model Evaluation</h1>

# %%
print('Time training:{} (s)'.format(time_training))
# Out:
# Time training:2729.5713787078857 (s)

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
test_dataset = Dataset(
    x_test_dir, 
    y_test_dir, 
    classes=CLASSES, 
    preprocessing=get_preprocessing(preprocess_input),
)

test_dataloader = Dataloder(test_dataset, batch_size=1, shuffle=False)

# %%
# load best weights
model.load_weights('./checkpoint/efficientnetb3_Unet.h5')

# %%
scores  = model.evaluate_generator(test_dataloader)
print("Loss:{:.5}".format(scores[0]))
for metric,value in zip(metrics,scores[1:]):
    print("mean {}:{:.5}".format(metric.__name__,value))
# Out:
# /home/waflol/anaconda3/lib/python3.8/site-packages/keras/engine/training.py:2006: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# Loss:0.43024
# mean iou_score:0.53489
# mean f1-score:0.61347

# %%
df = pd.DataFrame({'backbone':[BACKBONE],'model':['Unet'],'Time_training':[time_training],
                   'loss':[scores[0]],'Iou_score':[scores[1]]})

# %%
df
# Out:
#          backbone model  Time_training      loss  Iou_score
# 0  efficientnetb3  Unet    2729.571379  0.430244   0.534888

# %%
df.to_excel('Evaluation_model.xlsx')

# %% [markdown]
# <h1>Evaluation on Test</h1>

# %%
n = 5
ids = np.random.choice(np.arange(len(test_dataset)), size=n)

for i in ids:
    image, gt_mask = test_dataset[i]
    image = np.expand_dims(image, axis=0)
    pr_mask = model.predict(image)
    
    visualize(
        image=denormalize(image.squeeze()),
        gt_mask=gt_mask[...,3].squeeze(),
        pr_mask=pr_mask[...,3].squeeze(),
    )
