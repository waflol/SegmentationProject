# %% [markdown]
# <h1>Prepare Environment</h1>

# %%
from data_processing.Augmentation import *
from data_processing.helper import *

# %%
from tensorflow import keras
import tensorflow as tf
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
import time

# %% [markdown]
# <h1>Loading dataset</h1>

# %%
DATA_DIR = './CamVid/'

# %%
x_train_dir = os.path.join(DATA_DIR, 'train')
y_train_dir = os.path.join(DATA_DIR, 'trainannot')

x_valid_dir = os.path.join(DATA_DIR, 'val')
y_valid_dir = os.path.join(DATA_DIR, 'valannot')

x_test_dir = os.path.join(DATA_DIR, 'test')
y_test_dir = os.path.join(DATA_DIR, 'testannot')

# %%
# Lets look at data we have
"""
CLASSES = ['sky', 'building', 'pole', 'road', 'pavement', 
               'tree', 'signsymbol', 'fence', 'car', 
               'pedestrian', 'bicyclist', 'unlabelled']
"""
dataset = Dataset(x_train_dir, y_train_dir, 
                  classes = ['road', 'pavement', 'signsymbol','car', 
                             'pedestrian', 'bicyclist'])

image, mask = dataset[5] # get some sample

# %%
visualize(
    image=image, 
    road_mask=mask[..., 0].squeeze(),
    pavement_mask=mask[..., 1].squeeze(),
    signsymbol_mask=mask[..., 2].squeeze(),
)

# %%
visualize(
    image=image, 
    car_mask=mask[..., 3].squeeze(),
    pedestrian_mask=mask[..., 4].squeeze(),
    bicyclist_mask=mask[..., 5].squeeze(),
    background_mask=mask[..., 6].squeeze(),
)

# %% [markdown]
# <h1>Augmentation</h1>

# %%
dataset = Dataset(x_train_dir, y_train_dir, 
                  classes = ['road', 'pavement', 'signsymbol','car', 
                             'pedestrian', 'bicyclist'], 
                  augmentation=get_training_augmentation())
# Out:
# /home/waflol/anaconda3/envs/myenv/lib/python3.8/site-packages/albumentations/augmentations/transforms.py:1800: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(
# /home/waflol/anaconda3/envs/myenv/lib/python3.8/site-packages/albumentations/augmentations/transforms.py:1826: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(

# %%
image, mask = dataset[20] # get some sample

# %%
visualize(
    image=image, 
    road_mask=mask[..., 0].squeeze(),
    pavement_mask=mask[..., 1].squeeze(),
    signsymbol_mask=mask[..., 2].squeeze(),
)

# %%
visualize(
    image=image, 
    car_mask=mask[..., 3].squeeze(),
    pedestrian_mask=mask[..., 4].squeeze(),
    bicyclist_mask=mask[..., 5].squeeze(),
    background_mask=mask[..., 6].squeeze(),
)

# %% [markdown]
# <h1>Segmentation Model Training</h1>

# %%
import segmentation_models as sm
sm.set_framework('tf.keras')
# Out:
# Segmentation Models: using `keras` framework.

# %%
BACKBONE = 'vgg16'
BATCH_SIZE = 4
CLASSES = ['road', 'pavement', 'signsymbol','car', 'pedestrian', 'bicyclist']
LR = 0.0001

# Set number of epochs
EPOCHS = 250

# Patience for the learning rate
LR_PATIENCE = 5

# Patience for early stopping
STOPPING_PATIENCE = 30

preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# define network parameters
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

#create model
model = sm.FPN(BACKBONE, classes=n_classes, activation=activation)
# Out:
# 2021-11-28 18:51:28.013455: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-28 18:51:28.018875: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-28 18:51:28.019267: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-28 18:51:28.019925: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-28 18:51:28.020308: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-28 18:51:28.020666: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-28 18:51:28.020968: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-28 18:51:28.400662: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-28 18:51:28.401014: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-28 18:51:28.401306: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-28 18:51:28.401573: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5093 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
# define optomizer
optim = keras.optimizers.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
# set class weights for dice_loss (car: 1.; pedestrian: 2.; background: 0.5;)
dice_loss = sm.losses.DiceLoss(class_weights=np.array([1, 2, 3,4,5,6,0.5])) 
focal_loss = sm.losses.BinaryFocalLoss() if n_classes == 1 else sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 

metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, loss = total_loss, metrics = metrics)

# %%
model.summary(                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         )
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  block1_conv1 (Conv2D)          (None, None, None,   1792        ['input_1[0][0]']
#                                 64)
#
#  block1_conv2 (Conv2D)          (None, None, None,   36928       ['block1_conv1[0][0]']
#                                 64)
#
#  block1_pool (MaxPooling2D)     (None, None, None,   0           ['block1_conv2[0][0]']
#                                 64)
#
#  block2_conv1 (Conv2D)          (None, None, None,   73856       ['block1_pool[0][0]']
#                                 128)
#
#  block2_conv2 (Conv2D)          (None, None, None,   147584      ['block2_conv1[0][0]']
#                                 128)
#
#  block2_pool (MaxPooling2D)     (None, None, None,   0           ['block2_conv2[0][0]']
#                                 128)
#
#  block3_conv1 (Conv2D)          (None, None, None,   295168      ['block2_pool[0][0]']
#                                 256)
#
#  block3_conv2 (Conv2D)          (None, None, None,   590080      ['block3_conv1[0][0]']
#                                 256)
#
#  block3_conv3 (Conv2D)          (None, None, None,   590080      ['block3_conv2[0][0]']
#                                 256)
#
#  block3_pool (MaxPooling2D)     (None, None, None,   0           ['block3_conv3[0][0]']
#                                 256)
#
#  block4_conv1 (Conv2D)          (None, None, None,   1180160     ['block3_pool[0][0]']
#                                 512)
#
#  block4_conv2 (Conv2D)          (None, None, None,   2359808     ['block4_conv1[0][0]']
#                                 512)
#
#  block4_conv3 (Conv2D)          (None, None, None,   2359808     ['block4_conv2[0][0]']
#                                 512)
#
#  block4_pool (MaxPooling2D)     (None, None, None,   0           ['block4_conv3[0][0]']
#                                 512)
#
#  block5_conv1 (Conv2D)          (None, None, None,   2359808     ['block4_pool[0][0]']
#                                 512)
#
#  block5_conv2 (Conv2D)          (None, None, None,   2359808     ['block5_conv1[0][0]']
#                                 512)
#
#  block5_conv3 (Conv2D)          (None, None, None,   2359808     ['block5_conv2[0][0]']
#                                 512)
#
#  block5_pool (MaxPooling2D)     (None, None, None,   0           ['block5_conv3[0][0]']
#                                 512)
#
#  fpn_stage_p5_pre_conv (Conv2D)  (None, None, None,   131328     ['block5_pool[0][0]']
#                                 256)
#
#  fpn_stage_p5_upsampling (UpSam  (None, None, None,   0          ['fpn_stage_p5_pre_conv[0][0]']
#  pling2D)                       256)
#
#  fpn_stage_p5_conv (Conv2D)     (None, None, None,   131328      ['block5_conv3[0][0]']
#                                 256)
#
#  fpn_stage_p5_add (Add)         (None, None, None,   0           ['fpn_stage_p5_upsampling[0][0]',
#                                 256)                              'fpn_stage_p5_conv[0][0]']
#
#  fpn_stage_p4_upsampling (UpSam  (None, None, None,   0          ['fpn_stage_p5_add[0][0]']
#  pling2D)                       256)
#
#  fpn_stage_p4_conv (Conv2D)     (None, None, None,   131328      ['block4_conv3[0][0]']
#                                 256)
#
#  fpn_stage_p4_add (Add)         (None, None, None,   0           ['fpn_stage_p4_upsampling[0][0]',
#                                 256)                              'fpn_stage_p4_conv[0][0]']
#
#  fpn_stage_p3_upsampling (UpSam  (None, None, None,   0          ['fpn_stage_p4_add[0][0]']
#  pling2D)                       256)
#
#  fpn_stage_p3_conv (Conv2D)     (None, None, None,   65792       ['block3_conv3[0][0]']
#                                 256)
#
#  fpn_stage_p3_add (Add)         (None, None, None,   0           ['fpn_stage_p3_upsampling[0][0]',
#                                 256)                              'fpn_stage_p3_conv[0][0]']
#
#  fpn_stage_p2_upsampling (UpSam  (None, None, None,   0          ['fpn_stage_p3_add[0][0]']
#  pling2D)                       256)
#
#  fpn_stage_p2_conv (Conv2D)     (None, None, None,   33024       ['block2_conv2[0][0]']
#                                 256)
#
#  fpn_stage_p2_add (Add)         (None, None, None,   0           ['fpn_stage_p2_upsampling[0][0]',
#                                 256)                              'fpn_stage_p2_conv[0][0]']
#
#  segm_stage3a_conv (Conv2D)     (None, None, None,   294912      ['fpn_stage_p3_add[0][0]']
#                                 128)
#
#  segm_stage4a_conv (Conv2D)     (None, None, None,   294912      ['fpn_stage_p4_add[0][0]']
#                                 128)
#
#  segm_stage5a_conv (Conv2D)     (None, None, None,   294912      ['fpn_stage_p5_add[0][0]']
#                                 128)
#
#  segm_stage2a_conv (Conv2D)     (None, None, None,   294912      ['fpn_stage_p2_add[0][0]']
#                                 128)
#
#  segm_stage3a_bn (BatchNormaliz  (None, None, None,   512        ['segm_stage3a_conv[0][0]']
#  ation)                         128)
#
#  segm_stage4a_bn (BatchNormaliz  (None, None, None,   512        ['segm_stage4a_conv[0][0]']
#  ation)                         128)
#
#  segm_stage5a_bn (BatchNormaliz  (None, None, None,   512        ['segm_stage5a_conv[0][0]']
#  ation)                         128)
#
#  segm_stage2a_bn (BatchNormaliz  (None, None, None,   512        ['segm_stage2a_conv[0][0]']
#  ation)                         128)
#
#  segm_stage3a_relu (Activation)  (None, None, None,   0          ['segm_stage3a_bn[0][0]']
#                                 128)
#
#  segm_stage4a_relu (Activation)  (None, None, None,   0          ['segm_stage4a_bn[0][0]']
#                                 128)
#
#  segm_stage5a_relu (Activation)  (None, None, None,   0          ['segm_stage5a_bn[0][0]']
#                                 128)
#
#  segm_stage2a_relu (Activation)  (None, None, None,   0          ['segm_stage2a_bn[0][0]']
#                                 128)
#
#  segm_stage3b_conv (Conv2D)     (None, None, None,   147456      ['segm_stage3a_relu[0][0]']
#                                 128)
#
#  segm_stage4b_conv (Conv2D)     (None, None, None,   147456      ['segm_stage4a_relu[0][0]']
#                                 128)
#
#  segm_stage5b_conv (Conv2D)     (None, None, None,   147456      ['segm_stage5a_relu[0][0]']
#                                 128)
#
#  segm_stage2b_conv (Conv2D)     (None, None, None,   147456      ['segm_stage2a_relu[0][0]']
#                                 128)
#
#  segm_stage3b_bn (BatchNormaliz  (None, None, None,   512        ['segm_stage3b_conv[0][0]']
#  ation)                         128)
#
#  segm_stage4b_bn (BatchNormaliz  (None, None, None,   512        ['segm_stage4b_conv[0][0]']
#  ation)                         128)
#
#  segm_stage5b_bn (BatchNormaliz  (None, None, None,   512        ['segm_stage5b_conv[0][0]']
#  ation)                         128)
#
#  segm_stage2b_bn (BatchNormaliz  (None, None, None,   512        ['segm_stage2b_conv[0][0]']
#  ation)                         128)
#
#  segm_stage3b_relu (Activation)  (None, None, None,   0          ['segm_stage3b_bn[0][0]']
#                                 128)
#
#  segm_stage4b_relu (Activation)  (None, None, None,   0          ['segm_stage4b_bn[0][0]']
#                                 128)
#
#  segm_stage5b_relu (Activation)  (None, None, None,   0          ['segm_stage5b_bn[0][0]']
#                                 128)
#
#  segm_stage2b_relu (Activation)  (None, None, None,   0          ['segm_stage2b_bn[0][0]']
#                                 128)
#
#  upsampling_stage3 (UpSampling2  (None, None, None,   0          ['segm_stage3b_relu[0][0]']
#  D)                             128)
#
#  upsampling_stage4 (UpSampling2  (None, None, None,   0          ['segm_stage4b_relu[0][0]']
#  D)                             128)
#
#  upsampling_stage5 (UpSampling2  (None, None, None,   0          ['segm_stage5b_relu[0][0]']
#  D)                             128)
#
#  aggregation_concat (Concatenat  (None, None, None,   0          ['segm_stage2b_relu[0][0]',
#  e)                             512)                              'upsampling_stage3[0][0]',
#                                                                   'upsampling_stage4[0][0]',
#                                                                   'upsampling_stage5[0][0]']
#
#  final_stage_conv (Conv2D)      (None, None, None,   589824      ['aggregation_concat[0][0]']
#                                 128)
#
#  final_stage_bn (BatchNormaliza  (None, None, None,   512        ['final_stage_conv[0][0]']
#  tion)                          128)
#
#  final_stage_relu (Activation)  (None, None, None,   0           ['final_stage_bn[0][0]']
#                                 128)
#
#  final_upsampling (UpSampling2D  (None, None, None,   0          ['final_stage_relu[0][0]']
#  )                              128)
#
#  head_conv (Conv2D)             (None, None, None,   8071        ['final_upsampling[0][0]']
#                                 7)
#
#  softmax (Activation)           (None, None, None,   0           ['head_conv[0][0]']
#                                 7)
#
# ==================================================================================================
# Total params: 17,579,463
# Trainable params: 17,577,159
# Non-trainable params: 2,304
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
assert train_dataloader[0][0].shape == (BATCH_SIZE, 320, 320, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 320, 320, n_classes)
# Out:
# /home/waflol/anaconda3/envs/myenv/lib/python3.8/site-packages/albumentations/augmentations/transforms.py:1800: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(
# /home/waflol/anaconda3/envs/myenv/lib/python3.8/site-packages/albumentations/augmentations/transforms.py:1826: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(

# %%
from tensorflow.keras.callbacks import EarlyStopping
# define callbacks for learning rate scheduling and best checkpoints saving
checkpoint = tf.keras.callbacks.ModelCheckpoint('./checkpoint/vgg16_FPN.h5', monitor='val_loss',save_weights_only=True, save_best_only=True, mode='min')
learning_rate = tf.keras.callbacks.ReduceLROnPlateau(patience=LR_PATIENCE, verbose=1, factor=0.5, min_delta=0.00001)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=STOPPING_PATIENCE, verbose=1, restore_best_weights=True)

# %%
# train model
pre_train = time.time()
history = model.fit_generator(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=EPOCHS, 
    callbacks=[learning_rate,early_stopping,checkpoint], 
    validation_data=valid_dataloader, 
    validation_steps=len(valid_dataloader),
)
time_training = time.time() - pre_train
# Out:
# /tmp/ipykernel_100608/1794659408.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/250
# 2021-11-28 18:51:32.588720: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8204
# 91/91 [==============================] - 60s 566ms/step - loss: 0.6247 - iou_score: 0.3658 - f1-score: 0.4436 - val_loss: 0.6077 - val_iou_score: 0.4040 - val_f1-score: 0.4878 - lr: 1.0000e-04
# Epoch 2/250
# 91/91 [==============================] - 50s 548ms/step - loss: 0.5426 - iou_score: 0.4370 - f1-score: 0.5235 - val_loss: 0.5300 - val_iou_score: 0.4517 - val_f1-score: 0.5475 - lr: 1.0000e-04
# Epoch 3/250
# 91/91 [==============================] - 50s 550ms/step - loss: 0.5143 - iou_score: 0.4605 - f1-score: 0.5433 - val_loss: 0.4733 - val_iou_score: 0.5221 - val_f1-score: 0.6300 - lr: 1.0000e-04
250
# 91/91 [==============================] - 50s 546ms/step - loss: 0.3312 - iou_score: 0.6308 - f1-score: 0.7186 - val_loss: 0.2824 - val_iou_score: 0.6702 - val_f1-score: 0.7668 - lr: 1.9531e-07
# Epoch 94/250
# 91/91 [==============================] - 50s 546ms/step - loss: 0.3261 - iou_score: 0.6349 - f1-score: 0.7248 - val_loss: 0.2820 - val_iou_score: 0.6704 - val_f1-score: 0.7670 - lr: 1.9531e-07
# Epoch 95/250
# 91/91 [==============================] - ETA: 0s - loss: 0.3275 - iou_score: 0.6321 - f1-score: 0.7212
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# Restoring model weights from the end of the best epoch: 65.
# 91/91 [==============================] - 50s 546ms/step - loss: 0.3275 - iou_score: 0.6321 - f1-score: 0.7212 - val_loss: 0.2819 - val_iou_score: 0.6704 - val_f1-score: 0.7670 - lr: 1.9531e-07
# Epoch 00095: early stopping

# %% [markdown]
# <h1>Model Evaluation</h1>

# %%
print('Time training:{} (s)'.format(time_training))
# Out:
# Time training:4756.101278781891 (s)

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
test_dataset = Dataset(
    x_test_dir, 
    y_test_dir, 
    classes=CLASSES, 
    preprocessing=get_preprocessing(preprocess_input),
)

test_dataloader = Dataloder(test_dataset, batch_size=1, shuffle=False)

# %%
# load best weights
model.load_weights('./checkpoint/vgg16_FPN.h5')

# %%
scores  = model.evaluate_generator(test_dataloader)
print("Loss:{:.5}".format(scores[0]))
for metric,value in zip(metrics,scores[1:]):
    print("mean {}:{:.5}".format(metric.__name__,value))
# Out:
# /tmp/ipykernel_100608/2477453485.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   scores  = model.evaluate_generator(test_dataloader)
# Loss:0.42497
# mean iou_score:0.54429
# mean f1-score:0.6203

# %%
df = pd.DataFrame({'backbone':[BACKBONE],'model':['FPN'],'Time_training':[time_training],
                   'loss':[scores[0]],'Iou_score':[scores[1]]})

# %%
df
# Out:
#   backbone model  Time_training      loss  Iou_score
# 0    vgg16   FPN    4756.101279  0.424975    0.54429

# %%
data = pd.read_excel('Evaluation_model.xlsx')
data = data[['backbone','model','Time_training','loss','Iou_score']]
data
# Out:
#          backbone model  Time_training      loss  Iou_score
# 0           vgg16  Unet    4716.292528  0.450795   0.524129
# 1        resnet50  Unet    2754.380667  0.436002   0.532806
# 2     mobilenetv2  Unet    2111.109734  0.441323   0.526182
# 3     mobilenetv2   FPN    3336.091649  0.434233   0.532188
# 4     inceptionv3   FPN    4416.651027  0.433190   0.534531
# 5  efficientnetb3  Unet    3795.621106  0.429767   0.537205
# 6  efficientnetb3   FPN    5052.327916  0.428663   0.537585
# 7     inceptionv3  Unet    8913.769664  0.443069   0.527323

# %%
df = pd.concat([df,data],axis=0)
df
# Out:
#          backbone model  Time_training      loss  Iou_score
# 0           vgg16   FPN    4756.101279  0.424975   0.544290
# 0           vgg16  Unet    4716.292528  0.450795   0.524129
# 1        resnet50  Unet    2754.380667  0.436002   0.532806
# 2     mobilenetv2  Unet    2111.109734  0.441323   0.526182
# 3     mobilenetv2   FPN    3336.091649  0.434233   0.532188
# 4     inceptionv3   FPN    4416.651027  0.433190   0.534531
# 5  efficientnetb3  Unet    3795.621106  0.429767   0.537205
# 6  efficientnetb3   FPN    5052.327916  0.428663   0.537585
# 7     inceptionv3  Unet    8913.769664  0.443069   0.527323

# %%
df.to_excel('Evaluation_model.xlsx')

# %% [markdown]
# <h1>Evaluation on Test</h1>

# %%
n = 5
ids = np.random.choice(np.arange(len(test_dataset)), size=n)

for i in ids:
    image, gt_mask = test_dataset[i]
    image = np.expand_dims(image, axis=0)
    pr_mask = model.predict(image)
    
    visualize(
        image=denormalize(image.squeeze()),
        gt_mask=gt_mask[...,3].squeeze(),
        pr_mask=pr_mask[...,3].squeeze(),
    )
